# %%
using Pkg

cd(@__DIR__)
Pkg.activate("../..")

include("../src/OPTwrappers.jl") 
include("../src/OPTnewEngines.jl")  # I do this to test
# Out:
#   Activating project at `~/Documents/Github/flexibleDSM`
# ┌ Warning: Metal.jl not available or no Metal devices detected: UndefVarError(:Metal, 0x0000000000009968, Main)
# └ @ Main /Users/nobuaki/Documents/Github/flexibleDSM/OPTmotors/src/batchEnzyme.jl:27
# constructingNumericalDiscretisedEquations (generic function with 2 methods)

# %%
famousEquationType="2DacousticTime"
exprs,fields,vars,extexprs,extfields,extvars,coordinates,∂,∂²=famousEquations(famousEquationType)
# Out:
# (Differential(t)(Differential(t)(u(x, y, t))) - (Differential(x)(Differential(x)(u(x, y, t))) + Differential(y)(Differential(y)(u(x, y, t))))*(v(x, y)^2), u(x, y, t), v(x, y), f(x, y, t), f(x, y, t), 1, (x, y, t), Any[Differential(x), Differential(y), Differential(t)], Any[Differential(x) ∘ Differential(x), Differential(y) ∘ Differential(y), Differential(t) ∘ Differential(t)])

# %%
multiOrdersIndices = CartesianIndices((5, 5, 5))
# Out:
# CartesianIndices((5, 5, 5))

# %%
pointsIndices = [[1, 1, 1] [1, 2, 1] [1, 3, 1]; [2, 1, 1] [2, 2, 1] [2, 3, 1]; [3, 1, 1] [3, 2, 1] [3, 3, 1];;; [1, 1, 2] [1, 2, 2] [1, 3, 2]; [2, 1, 2] [2, 2, 2] [2, 3, 2]; [3, 1, 2] [3, 2, 2] [3, 3, 2];;; [1, 1, 3] [1, 2, 3] [1, 3, 3]; [2, 1, 3] [2, 2, 3] [2, 3, 3]; [3, 1, 3] [3, 2, 3] [3, 3, 3]]
Δ = (1.0, 1.0, 1.0)
WorderBspline = [1, 1, 1]
modifiedμ = Any[Num[1 1 1; 3 3 3; 2.0 2.0 2.0;;; 1 1 1; 3 3 3; 2.0 2.0 2.0], Num[1 1 1; 3 3 3; 2.0 2.0 2.0;;; 1 1 1; 3 3 3; 2.0 2.0 2.0], Num[1 1 1; 3 3 3; 2.0 2.0 2.0;;; 1 1 1; 3 3 3; 2.0 2.0 2.0]]
# Out:
# 3-element Vector{Any}:
#  Num[1 1 1; 3 3 3; 2.0 2.0 2.0;;; 1 1 1; 3 3 3; 2.0 2.0 2.0]
#  Num[1 1 1; 3 3 3; 2.0 2.0 2.0;;; 1 1 1; 3 3 3; 2.0 2.0 2.0]
#  Num[1 1 1; 3 3 3; 2.0 2.0 2.0;;; 1 1 1; 3 3 3; 2.0 2.0 2.0]

# %%
coefInversionDict = @strdict coordinates multiOrdersIndices pointsIndices Δ WorderBspline modifiedμ
# Out:
# Dict{String, Any} with 6 entries:
#   "coordinates"        => (x, y, t)
#   "Δ"                  => (1.0, 1.0, 1.0)
#   "modifiedμ"          => Any[Num[1 1 1; 3 3 3; 2.0 2.0 2.0;;; 1 1 1; 3 3 3; 2.…
#   "WorderBspline"      => [1, 1, 1]
#   "multiOrdersIndices" => CartesianIndices((5, 5, 5))
#   "pointsIndices"      => [1 1 1; 1 2 3; … ; 1 2 3; 1 1 1;;; 1 1 1; 1 2 3; … ; …

# %%
output=myProduceOrLoad(TaylorCoefInversion,coefInversionDict,"taylorCoefInv")
# Out:
# ┌ Info: File /Users/nobuaki/Documents/Github/flexibleDSM/data/taylorCoefInv/taylorCoefInv_d35b00a6.jld2 does not exist. Producing it now...
# └ @ DrWatson /Users/nobuaki/.julia/packages/DrWatson/2QF5p/src/saving_files.jl:106
# (1, μ_oneD, (pointsIndices[μ_oneD])[iCoord], WorderBspline[iCoord] + 1, iCoord) = (1, 1, 1, 2, 1)
# (tmp1, tmp2, tmp3) = (1.0, 3.0, 2.0)
# BoundsError: attempt to access Int64 at index [2]
#
#
#
# Stacktrace:
#
#  [1] getindex
#
#    @ ./number.jl:98 [inlined]
#
#  [2] macro expansion
#
#    @ ./show.jl:1270 [inlined]
#
#  [3] TaylorCoefInversion(numberOfLs::Int64, numberOfEtas::Int64, multiOrdersIndices::CartesianIndices{3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}}, pointsIndices::Array{Int64, 3}, Δ::Tuple{Float64, Float64, Float64}, μ_oneD::Int64, WorderBspline::Vector{Int64}, modifiedμ::Vector{Any})
#
#    @ Main ~/Documents/Github/flexibleDSM/OPTmotors/src/OPTnewEngines.jl:224
#
#  [4] TaylorCoefInversion(coefInversionDict::Dict{String, Any})
#
#    @ Main ~/Documents/Github/flexibleDSM/OPTmotors/src/OPTnewEngines.jl:194
#
#  [5] produce_or_load(f::typeof(TaylorCoefInversion), config::Dict{String, Any}, path::String; suffix::String, prefix::String, tag::Bool, gitpath::String, loadfile::Bool, storepatch::Bool, force::Bool, verbose::Bool, wsave_kwargs::@NamedTuple{}, wload_kwargs::@NamedTuple{}, filename::var"#myProduceOrLoad##2#myProduceOrLoad##3"{String, Dict{String, Any}}, kwargs::@Kwargs{})
#
#    @ DrWatson ~/.julia/packages/DrWatson/2QF5p/src/saving_files.jl:108
#
#  [6] myProduceOrLoad(functionName::Function, paramDict::Dict{String, Any}, directoryName::String, prefixName::String)
#
#    @ Main ~/Documents/Github/flexibleDSM/OPTmotors/src/batchDrWatson.jl:27
#
#  [7] myProduceOrLoad(functionName::Function, paramDict::Dict{String, Any}, directoryName::String)
#
#    @ Main ~/Documents/Github/flexibleDSM/OPTmotors/src/batchDrWatson.jl:13
#
#  [8] top-level scope
#
#    @ ~/Documents/Github/flexibleDSM/OPTmotors/misc/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W5sZmlsZQ==.jl:1
